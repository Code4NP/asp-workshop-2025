# %%
# https://www.ncbi.nlm.nih.gov/biosample/SAMN36419051/
# https://www.ncbi.nlm.nih.gov/datasets/docs/v2/api/rest-api/
# https://www.ncbi.nlm.nih.gov/datasets/docs/v2/api/api-keys/#get-your-api-key

import os
import requests
import pprint

import panadas as pd
from rich import inspect
from dotenv import load_dotenv

dotenv_path = "/home/chase/asp_workshop_keys"
load_dotenv(dotenv_path=dotenv_path)

NCBI_KEY = os.getenv("NCBI_KEY", "your_key_here")

# %%
class Organism:
    def __init__(self, genome_id):
        self.id = genome_id
        self.data = self._get_data()
        
    def _get_json(self, url, api_key=None):
        headers = {'accept': 'application/json'}
        if api_key:
            headers["api-key"] = api_key
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            return response.json()
        except requests.RequestException as e:
            print(f"Error fetching data from: {e}")
            return None
        
    def _get_data(self):
        url = f"https://api.ncbi.nlm.nih.gov/datasets/v2/genome/accession/{self.id}/dataset_report"
        return self._get_json(url, api_key=NCBI_KEY)
    
    def what_am_i(self):
        print(f'I am a: "{self.data['reports'][0]['organism']['common_name']}"')

# %%
a=Organism(genome_id = "GCF_000001635")
a.what_am_i()
# Out:
# I am a: "house mouse"

# %%
a.data
# Out:
# {'reports': [{'accession': 'GCF_000001635.27',
#    'current_accession': 'GCF_000001635.27',
#    'paired_accession': 'GCA_000001635.9',
#    'source_database': 'SOURCE_DATABASE_REFSEQ',
#    'organism': {'tax_id': 10090,
#     'organism_name': 'Mus musculus',
#     'common_name': 'house mouse',
#     'infraspecific_names': {'strain': 'C57BL/6J'}},
#    'assembly_info': {'assembly_level': 'Chromosome',
#     'assembly_status': 'current',
#     'paired_assembly': {'accession': 'GCA_000001635.9', 'status': 'current'},
#     'assembly_name': 'GRCm39',
#     'assembly_type': 'haploid',
#     'bioproject_lineage': [{'bioprojects': [{'accession': 'PRJNA20689',
#         'title': 'Genome sequence finishing for Mus musculus, currently maintained by the Genome Reference Consortium (GRC)'}]}],
#     'bioproject_accession': 'PRJNA20689',
#     'release_date': '2020-06-24',
#     'description': 'Genome Reference Consortium Mouse Build 39',
#     'submitter': 'Genome Reference Consortium',
#     'refseq_category': 'reference genome',
#     'synonym': 'mm39',
#     'blast_url': 'https://blast.ncbi.nlm.nih.gov/Blast.cgi?PAGE_TYPE=BlastSearch&PROG_DEF=blastn&BLAST_SPEC=GDH_GCF_000001635.27'},
#    'assembly_stats': {'total_number_of_chromosomes': 21,
#     'total_sequence_length': '2728206152',
#     'total_ungapped_length': '2654605538',
#     'number_of_contigs': 305,
#     'contig_n50': 59462871,
#     'contig_l50': 15,
#     'number_of_scaffolds': 101,
#     'scaffold_n50': 106145001,
#     'scaffold_l50': 11,
#     'gaps_between_scaffolds_count': 143,
#     'number_of_component_sequences': 21254,
#     'atgc_count': '3765774759',
#     'gc_count': '1573609204',
#     'gc_percent': 42,
#     'number_of_organelles': 1},
#    'organelle_info': [{'description': 'Mitochondrion',
#      'total_seq_length': '16299',
#      'submitter': 'Genome Reference Consortium'}],
#    'annotation_info': {'name': 'GCF_000001635.27-RS_2024_02',
#     'provider': 'NCBI RefSeq',
#     'release_date': '2024-02-01',
#     'report_url': 'https://www.ncbi.nlm.nih.gov/genome/annotation_euk/Mus_musculus/GCF_000001635.27-RS_2024_02.html',
#     'stats': {'gene_counts': {'total': 50763,
#       'protein_coding': 22198,
#       'non_coding': 17705,
#       'pseudogene': 10363,
#       'other': 497}},
#     'busco': {'busco_lineage': 'glires_odb10',
#      'busco_ver': '4.1.4',
#      'complete': 0.9946369,
#      'single_copy': 0.98594,
#      'duplicated': 0.008696913,
#      'fragmented': 0.001594434,
#      'missing': 0.0037686622,
#      'total_count': '13798'},
#     'method': 'Best-placed RefSeq; Gnomon; RefSeqFE; cmsearch; tRNAscan-SE',
#     'pipeline': 'NCBI eukaryotic genome annotation pipeline',
#     'software_version': '10.2',
#     'status': 'Updated annotation'}}],
#  'total_count': 1}

# %%
a=Organism("GCF_038242915")
a.what_am_i()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 2
#       1 a=Organism("GCF_038242915")
# ----> 2 a.what_am_i()
#
# Cell In[26], line 23, in Organism.what_am_i(self)
#      22 def what_am_i(self):
# ---> 23     print(f'I am a: "{self.data['reports'][0]['organism']['common_name']}"')
#
# KeyError: 'common_name'

# %% [markdown]
# ######## 2 ########

# %%
class Organism:
    def __init__(self, genome_id):
        self.id = genome_id
    def what_am_i(self):
        url = f"https://api.ncbi.nlm.nih.gov/datasets/v2/genome/accession/{self.id}/dataset_report"
        try:
            response = requests.get(url, headers={'accept': 'application/json', "api-key": NCBI_KEY})
            response.raise_for_status()
            data = response.json()
            if 'common_name' in data['reports'][0]['organism']:
                print(f"I am a: {data['reports'][0]['organism']['common_name']}")
            elif 'organism_name' in data['reports'][0]['organism']:
                print(f"🤓 I am a: {data['reports'][0]['organism']['organism_name']}")
            else:
                print("I don't know")
        except requests.RequestException as e:
            print(f"Error fetching data from NCBI: {e}")

# %%
a=Organism("GCF_000001635")
a.what_am_i()
# Out:
# I am a: house mouse

# %%
a=Organism("GCF_038242915")
a.what_am_i()
# Out:
# 🤓 I am a: Streptomyces albidoflavus

# %% [markdown]
# ######## 3 ########

# %%
class Organism:
    def __init__(self, genome_id):
        self.id = genome_id
    @staticmethod
    def _extract_taxid(data):
        try:
            return data['reports'][0]['organism']['tax_id']
        except (KeyError, IndexError):
            return None
    @staticmethod
    def _extract_assembly_name(data):
        try:
            return data['reports'][0]['assembly_info']['assembly_name']
        except (KeyError, IndexError):
            return None
    def set_info(self):
        url = f"https://api.ncbi.nlm.nih.gov/datasets/v2/genome/accession/{self.id}/dataset_report"
        try:
            response = requests.get(url, headers={'accept': 'application/json', "api-key": NCBI_KEY})
            response.raise_for_status()
        except requests.RequestException as e:
            print(f"Error fetching data from NCBI: {e}")
        # assign taxid
        self.taxid = self._extract_taxid(response.json())
        # assign assembly_name
        self.assembly_name = self._extract_assembly_name(response.json())

# %%
a = Organism("GCF_000001635.27")

# %%
a.taxid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 a.taxid
#
# AttributeError: 'Organism' object has no attribute 'taxid'

# %%
a.assembly_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 a.assembly_name
#
# AttributeError: 'Organism' object has no attribute 'assembly_name'

# %%
a.set_info()
a.taxid
a.assembly_name
# Out:
# 'GRCm39'

# %% [markdown]
# ######## 4 ########

# %%
class Organism:
    __slots__ = ['id', 'BLAST_LINK', 'GDV_LINK', 'FTP_LINK', 'ASSEMBLY_PUBMED', 'ASSEMBLY_NUCCORE', 'ASSEMBLY_NUCCORE_REFSEQ', 'ASSEMBLY_NUCCORE_GENBANK', 'CGV_LINK']
    def __init__(self, genome_id):
        self.id = genome_id
        self.get_outlinks()
    def get_outlinks(self):
        """Fetches assembly links from NCBI and assigns them to the instance attributes."""
        url = f"https://api.ncbi.nlm.nih.gov/datasets/v2/genome/accession/{self.id}/links"
        try:
            response = requests.get(url, headers={'accept': 'application/json', "api-key": NCBI_KEY})
            response.raise_for_status()
            data = response.json()
            for i in data['assembly_links']:
                try:
                    link_type = i['assembly_link_type']
                    if link_type in self.__slots__:
                        setattr(self, link_type, i['resource_link'])
                except KeyError as e:
                    print(f"Missing key in assembly link data: {e}")
        except requests.RequestException as e:
            print(f"Error fetching data from NCBI: {e}")

# %%
a = Organism("GCF_000001635.27")

# %%
inspect(Organism, methods=True)
# Out:
# ╭────────────────────────────────────────── <class '__main__.Organism'> ──────────────────────────────────────────╮
# │ class Organism(genome_id):                                                                                      │
# │                                                                                                                 │
# │         ASSEMBLY_NUCCORE = <member 'ASSEMBLY_NUCCORE' of 'Organism' objects>                                    │
# │ ASSEMBLY_NUCCORE_GENBANK = <member 'ASSEMBLY_NUCCORE_GENBANK' of 'Organism' objects>                            │
# │  ASSEMBLY_NUCCORE_REFSEQ = <member 'ASSEMBLY_NUCCORE_REFSEQ' of 'Organism' objects>                             │
# │          ASSEMBLY_PUBMED = <member 'ASSEMBLY_PUBMED' of 'Organism' objects>                                     │
# │               BLAST_LINK = <member 'BLAST_LINK' of 'Organism' objects>                                          │
# │                 CGV_LINK = <member 'CGV_LINK' of 'Organism' objects>                                            │
# │                 FTP_LINK = <member 'FTP_LINK' of 'Organism' objects>                                            │
# │                 GDV_LINK = <member 'GDV_LINK' of 'Organism' objects>                                            │
# │                       id = <member 'id' of 'Organism' objects>                                                  │
# │             get_outlinks = def get_outlinks(self): Fetches assembly links from NCBI and assigns them to the     │
# │                            instance attributes.                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
inspect(a, methods=True)
# Out:
# ╭────────────────────────────────────────── <class '__main__.Organism'> ──────────────────────────────────────────╮
# │ ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────╮ │
# │ │ <__main__.Organism object at 0x7613dfe5e420>                                                                │ │
# │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                                 │
# │         ASSEMBLY_NUCCORE = 'https://www.ncbi.nlm.nih.gov/nuccore/?from_uid=7358741&linkname=assembly_nuccore_r… │
# │ ASSEMBLY_NUCCORE_GENBANK = 'https://www.ncbi.nlm.nih.gov/nuccore/?from_uid=7358741&linkname=assembly_nuccore_i… │
# │  ASSEMBLY_NUCCORE_REFSEQ = 'https://www.ncbi.nlm.nih.gov/nuccore/?from_uid=7358741&linkname=assembly_nuccore_r… │
# │          ASSEMBLY_PUBMED = 'https://www.ncbi.nlm.nih.gov/nuccore/?from_uid=7358741&linkname=assembly_pubmed'    │
# │               BLAST_LINK = 'https://blast.ncbi.nlm.nih.gov/Blast.cgi?PAGE_TYPE=BlastSearch&PROG_DEF=blastn&BLA… │
# │                 CGV_LINK = 'https://www.ncbi.nlm.nih.gov/cgv/GCF_000001635.27'                                  │
# │                 FTP_LINK = 'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/635/GCF_000001635.27_GRCm39'   │
# │                 GDV_LINK = 'https://www.ncbi.nlm.nih.gov/genome/gdv/browser/genome/?id=GCF_000001635.27'        │
# │                       id = 'GCF_000001635.27'                                                                   │
# │             get_outlinks = def get_outlinks(): Fetches assembly links from NCBI and assigns them to the         │
# │                            instance attributes.                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
a.BLAST_LINK
# Out:
# 'https://blast.ncbi.nlm.nih.gov/Blast.cgi?PAGE_TYPE=BlastSearch&PROG_DEF=blastn&BLAST_SPEC=GDH_GCF_000001635.27'

# %% [markdown]
# # Taxonomy

# %%
curl -X POST "https://api.ncbi.nlm.nih.gov/datasets/v2/taxonomy/taxon_suggest" \
 -H 'accept: application/json'\
 -H 'content-type: application/json' \
 -d '{"taxon_query":"hum"}'

# %%
try:
    response = requests.post(
        "https://api.ncbi.nlm.nih.gov/datasets/v2/taxonomy/taxon_suggest",
        headers={'accept': 'application/json', 'content-type': 'application/json'},
        json={"taxon_query": "Streptomyces", "tax_rank_filter": "higher_taxon", "exact_match": True}
    )
    response.raise_for_status()
    taxon = response.json()
    print(taxon)
except requests.RequestException as e:
    print(f"Error fetching data from NCBI: {e}")
# Out:
# {'sci_name_and_ids': [{'sci_name': 'Streptomyces', 'tax_id': '1883', 'matched_term': 'Streptomyces', 'rank': 'GENUS'}]}

# %%
# "https://api.ncbi.nlm.nih.gov/datasets/v2/taxonomy/taxon/1883/dataset_report" 

taxid = taxon['sci_name_and_ids'][0]['tax_id']

try: 
    response = requests.get(
        f"https://api.ncbi.nlm.nih.gov/datasets/v2/taxonomy/taxon/{taxid}/dataset_report",
        headers={'accept': 'application/json', "api-key": NCBI_KEY}
    )
    response.raise_for_status()
    data = response.json()
    pprint.pprint(data)
except requests.RequestException as e:
    print(f"Error fetching data from NCBI: {e}")
# Out:
# {'reports': [{'query': ['1883'],
#               'taxonomy': {'children': [89304,
#                                         2593676,
#                                         60449,
#                                         1464011,
#                                         1517690,
#                                         1433417,
#                                         1521032,
#                                         1520577,
#                                         1433415,
#                                         1045501,
#                                         2053010,
#                                         1073330,
#                                         476556,
#                                         1818004,
#                                         1300267,
#                                         1981977,
#                                         68286,
#                                         1042984,
#                                         156453,
#                                         654447,
#                                         3102929,
#                                         67386,
#                                         66378,
#                                         31948,
#                                         78510,
#                                         1648182,
#                                         2989713,
#                                         1142239,
#                                         285514,
#                                         1807871,
#                                         933941,
#                                         264733,
#                                         1038928,
#                                         1565415,
#                                         2656783,
#                                         2665720,
#                                         408015,
#                                         67385,
#                                         68285,
#                                         67384,
#                                         2768069,
#                                         1196353,
#                                         1768091,
#                                         68284,
#                                         476555,
#                                         43759,
#                                         141454,
#                                         67383,
#                                         1441876,
#                                         67581,
#                                         68283,
#                                         196386,
#                                         1938,
#                                         284041,
#                                         68282,
#                                         68281,
#                                         887475,
#                                         173862,
#                                         48665,
#                                         1961,
#                                         285572,
#                                         285474,
#                                         329528,
#                                         66377,
#                                         67381,
#                                         67380,
#                                         2839105,
#                                         1936,
#                                         284042,
#                                         2867121,
#                                         67379,
#                                         67377,
#                                         1960,
#                                         3051092,
#                                         362257,
#                                         29309,
#                                         67375,
#                                         1695161,
#                                         66432,
#                                         2826946,
#                                         54571,
#                                         1701086,
#                                         67374,
#                                         51202,
#                                         319468,
#                                         285451,
#                                         67373,
#                                         285489,
#                                         284040,
#                                         101511,
#                                         2665498,
#                                         1775131,
#                                         1048205,
#                                         67371,
#                                         2681492,
#                                         85558,
#                                         948699,
#                                         2100528,
#                                         68279,
#                                         156423,
#                                         363752,
#                                         2969889,
#                                         68278,
#                                         47759,
#                                         2923272,
#                                         285482,
#                                         83656,
#                                         285546,
#                                         3034234,
#                                         83381,
#                                         3406573,
#                                         367827,
#                                         2182797,
#                                         2483353,
#                                         2651189,
#                                         2054410,
#                                         2293568,
#                                         45399,
#                                         2816232,
#                                         285488,
#                                         1124239,
#                                         55952,
#                                         67369,
#                                         285487,
#                                         68276,
#                                         2689386,
#                                         2174846,
#                                         2382123,
#                                         66431,
#                                         1718436,
#                                         551547,
#                                         1934,
#                                         1952,
#                                         80858,
#                                         161482,
#                                         149538,
#                                         66905,
#                                         285537,
#                                         44033,
#                                         285540,
#                                         75292,
#                                         67589,
#                                         44061,
#                                         106355,
#                                         285538,
#                                         78356,
#                                         285539,
#                                         2933609,
#                                         59299,
#                                         59298,
#                                         285541,
#                                         985760,
#                                         65605,
#                                         68275,
#                                         67368,
#                                         29308,
#                                         1932,
#                                         1447783,
#                                         2720021,
#                                         565073,
#                                         2919940,
#                                         2780544,
#                                         67367,
#                                         3078565,
#                                         2569853,
#                                         68273,
#                                         2569858,
#                                         2820809,
#                                         330919,
#                                         3156398,
#                                         76729,
#                                         415721,
#                                         487165,
#                                         285530,
#                                         265730,
#                                         47758,
#                                         68272,
#                                         436397,
#                                         882404,
#                                         36818,
#                                         2065372,
#                                         173861,
#                                         3344656,
#                                         3375367,
#                                         146820,
#                                         68271,
#                                         887469,
#                                         543535,
#                                         284039,
#                                         2315329,
#                                         1690221,
#                                         565072,
#                                         67366,
#                                         2812904,
#                                         299717,
#                                         2720606,
#                                         66376,
#                                         284043,
#                                         2872623,
#                                         2927582,
#                                         2906474,
#                                         285520,
#                                         285519,
#                                         2800380,
#                                         195801,
#                                         68270,
#                                         498367,
#                                         297584,
#                                         67365,
#                                         68269,
#                                         1459950,
#                                         78355,
#                                         2100817,
#                                         3043614,
#                                         3081768,
#                                         3231716,
#                                         2683255,
#                                         226217,
#                                         1387713,
#                                         2585196,
#                                         3127701,
#                                         67364,
#                                         67363,
#                                         1274988,
#                                         3034235,
#                                         1765722,
#                                         2803812,
#                                         545123,
#                                         2802281,
#                                         2871810,
#                                         1274986,
#                                         68268,
#                                         285507,
#                                         943815,
#                                         310041,
#                                         653357,
#                                         1302728,
#                                         285486,
#                                         2666250,
#                                         156648,
#                                         73044,
#                                         285513,
#                                         2873384,
#                                         1617721,
#                                         3383721,
#                                         555059,
#                                         452529,
#                                         104206,
#                                         1957,
#                                         285544,
#                                         1930,
#                                         2711217,
#                                         285577,
#                                         1521027,
#                                         1266772,
#                                         68267,
#                                         285455,
#                                         568869,
#                                         238877,
#                                         285536,
#                                         193460,
#                                         459658,
#                                         3075530,
#                                         97400,
#                                         2762598,
#                                         1813820,
#                                         285576,
#                                         285525,
#                                         149537,
#                                         285506,
#                                         1520582,
#                                         295838,
#                                         2967341,
#                                         430060,
#                                         565074,
#                                         97402,
#                                         285473,
#                                         285549,
#                                         285531,
#                                         67362,
#                                         516457,
#                                         83378,
#                                         359131,
#                                         66430,
#                                         67361,
#                                         285542,
#                                         67360,
#                                         66429,
#                                         285472,
#                                         67359,
#                                         67358,
#                                         66904,
#                                         285471,
#                                         425669,
#                                         645168,
#                                         33902,
#                                         285502,
#                                         285450,
#                                         516456,
#                                         1972,
#                                         2768066,
#                                         1488406,
#                                         2508722,
#                                         225049,
#                                         68265,
#                                         1520576,
#                                         2044847,
#                                         2867164,
#                                         1520581,
#                                         68264,
#                                         1927,
#                                         504097,
#                                         80859,
#                                         1266770,
#                                         2564098,
#                                         2932493,
#                                         1367506,
#                                         146821,
#                                         1926,
#                                         2250578,
#                                         68263,
#                                         68262,
#                                         223296,
#                                         332591,
#                                         173860,
#                                         67355,
#                                         691266,
#                                         47762,
#                                         1925,
#                                         68261,
#                                         881807,
#                                         403935,
#                                         1750517,
#                                         67353,
#                                         2599401,
#                                         360709,
#                                         943816,
#                                         384641,
#                                         2970331,
#                                         2970734,
#                                         68260,
#                                         68259,
#                                         1951,
#                                         285479,
#                                         1924,
#                                         1464077,
#                                         164348,
#                                         68258,
#                                         68257,
#                                         2894086,
#                                         285444,
#                                         67348,
#                                         285512,
#                                         2867410,
#                                         38300,
#                                         3139917,
#                                         1169025,
#                                         887456,
#                                         67345,
#                                         67344,
#                                         3120506,
#                                         2798799,
#                                         2058924,
#                                         68255,
#                                         1282885,
#                                         1550619,
#                                         1617087,
#                                         67342,
#                                         2767826,
#                                         340148,
#                                         2666248,
#                                         1355015,
#                                         37480,
#                                         511811,
#                                         2814589,
#                                         285475,
#                                         225050,
#                                         58346,
#                                         285508,
#                                         2571125,
#                                         2884812,
#                                         1520580,
#                                         2860288,
#                                         285534,
#                                         28893,
#                                         722715,
#                                         1150371,
#                                         2724184,
#                                         1803180,
#                                         889792,
#                                         291370,
#                                         285510,
#                                         114685,
#                                         2653200,
#                                         68254,
#                                         2838332,
#                                         1950,
#                                         68253,
#                                         97399,
#                                         285551,
#                                         66902,
#                                         1650571,
#                                         66428,
#                                         146923,
#                                         68252,
#                                         92743,
#                                         328313,
#                                         68251,
#                                         66375,
#                                         132470,
#                                         363864,
#                                         1470261,
#                                         3035064,
#                                         363862,
#                                         2282738,
#                                         1701085,
#                                         68250,
#                                         3036494,
#                                         183408,
#                                         68249,
#                                         2705029,
#                                         285504,
#                                         1128682,
#                                         2681388,
#                                         68248,
#                                         249581,
#                                         593134,
#                                         1434886,
#                                         2867268,
#                                         67339,
#                                         68247,
#                                         66427,
#                                         68246,
#                                         1653177,
#                                         285485,
#                                         1963,
#                                         1550618,
#                                         47716,
#                                         1921,
#                                         68245,
#                                         358823,
#                                         3344655,
#                                         285496,
#                                         2944940,
#                                         1417980,
#                                         1520579,
#                                         47761,
#                                         1075402,
#                                         2663842,
#                                         2586640,
#                                         68244,
#                                         1971,
#                                         281713,
#                                         3154512,
#                                         66374,
#                                         38314,
#                                         40318,
#                                         67337,
#                                         66901,
#                                         193462,
#                                         68243,
#                                         164115,
#                                         28894,
#                                         2842201,
#                                         285470,
#                                         1920,
#                                         1827580,
#                                         66373,
#                                         67335,
#                                         42238,
#                                         55404,
#                                         486956,
#                                         68242,
#                                         67333,
#                                         68241,
#                                         2872625,
#                                         518642,
#                                         225048,
#                                         679319,
#                                         204925,
#                                         66690,
#                                         285447,
#                                         285484,
#                                         1949,
#                                         284036,
#                                         67332,
#                                         2802280,
#                                         33900,
#                                         224537,
#                                         285478,
#                                         1077944,
#                                         285528,
#                                         2577050,
#                                         1970,
#                                         2307129,
#                                         1226758,
#                                         3075523,
#                                         2666263,
#                                         2580423,
#                                         2798581,
#                                         371720,
#                                         1678012,
#                                         68240,
#                                         35621,
#                                         67331,
#                                         285518,
#                                         68239,
#                                         68238,
#                                         67329,
#                                         2586635,
#                                         3075542,
#                                         476552,
#                                         285483,
#                                         285469,
#                                         1689400,
#                                         178566,
#                                         1775132,
#                                         2938945,
#                                         1182637,
#                                         661169,
#                                         67326,
#                                         44060,
#                                         481003,
#                                         58345,
#                                         67324,
#                                         33904,
#                                         324855,
#                                         115828,
#                                         2922868,
#                                         582854,
#                                         2878388,
#                                         1817406,
#                                         1459942,
#                                         1077945,
#                                         1428628,
#                                         1578834,
#                                         1206892,
#                                         2164084,
#                                         1428626,
#                                         1918,
#                                         371722,
#                                         67323,
#                                         67322,
#                                         67321,
#                                         1934208,
#                                         44032,
#                                         68236,
#                                         1917,
#                                         2952607,
#                                         3134109,
#                                         1079983,
#                                         47763,
#                                         1546107,
#                                         2974589,
#                                         2654337,
#                                         2665721,
#                                         66425,
#                                         173856,
#                                         68234,
#                                         3043615,
#                                         2615112,
#                                         68233,
#                                         285500,
#                                         1520575,
#                                         173858,
#                                         68232,
#                                         1434255,
#                                         67320,
#                                         1775900,
#                                         3026192,
#                                         333384,
#                                         1535768,
#                                         67319,
#                                         1495572,
#                                         68231,
#                                         2945947,
#                                         200596,
#                                         1948,
#                                         68230,
#                                         28044,
#                                         2880933,
#                                         3075524,
#                                         700599,
#                                         68229,
#                                         390239,
#                                         282216,
#                                         285522,
#                                         1916,
#                                         1236314,
#                                         1520567,
#                                         67318,
#                                         3075543,
#                                         1915,
#                                         2823109,
#                                         2797636,
#                                         68228,
#                                         285468,
#                                         285467,
#                                         284035,
#                                         2306967,
#                                         2717324,
#                                         67317,
#                                         285566,
#                                         1437453,
#                                         68227,
#                                         67316,
#                                         67315,
#                                         285466,
#                                         1914,
#                                         67314,
#                                         39478,
#                                         67313,
#                                         1923961,
#                                         2717064,
#                                         324833,
#                                         766498,
#                                         3075520,
#                                         66900,
#                                         285554,
#                                         887464,
#                                         652943,
#                                         1470455,
#                                         1332838,
#                                         1500077,
#                                         285569,
#                                         67312,
#                                         68225,
#                                         1565034,
#                                         1612435,
#                                         67311,
#                                         1684313,
#                                         2838015,
#                                         516125,
#                                         1420899,
#                                         1520572,
#                                         97405,
#                                         67310,
#                                         864058,
#                                         2577098,
#                                         68223,
#                                         151424,
#                                         285517,
#                                         1946,
#                                         68222,
#                                         1187859,
#                                         67309,
#                                         212423,
#                                         936756,
#                                         1967,
#                                         1236311,
#                                         285495,
#                                         285491,
#                                         333725,
#                                         2780140,
#                                         1945,
#                                         3075532,
#                                         1434256,
#                                         235987,
#                                         1716141,
#                                         67308,
#                                         103232,
#                                         68221,
#                                         53449,
#                                         1520571,
#                                         2293571,
#                                         1764539,
#                                         68220,
#                                         417292,
#                                         284033,
#                                         665007,
#                                         887453,
#                                         285457,
#                                         1384038,
#                                         68219,
#                                         479410,
#                                         516360,
#                                         1520570,
#                                         1873719,
#                                         598549,
#                                         1377993,
#                                         1077946,
#                                         2932614,
#                                         52259,
#                                         2953240,
#                                         1428620,
#                                         2876027,
#                                         1854574,
#                                         476554,
#                                         1141874,
#                                         68218,
#                                         1520569,
#                                         1306990,
#                                         35620,
#                                         66424,
#                                         3075521,
#                                         244282,
#                                         2820085,
#                                         2839954,
#                                         132471,
#                                         3075519,
#                                         3065675,
#                                         887449,
#                                         284032,
#                                         67306,
#                                         945052,
#                                         229486,
#                                         3075538,
#                                         2839966,
#                                         67305,
#                                         2697029,
#                                         1176198,
#                                         3074435,
#                                         246615,
#                                         1181887,
#                                         2879846,
#                                         582855,
#                                         402648,
#                                         2886947,
#                                         364901,
#                                         1520568,
#                                         629295,
#                                         45398,
#                                         284636,
#                                         1910,
#                                         67304,
#                                         1943,
#                                         1520566,
#                                         66895,
#                                         29306,
#                                         1909,
#                                         67303,
#                                         2867193,
#                                         146922,
#                                         35619,
#                                         293372,
#                                         68214,
#                                         51201,
#                                         2993540,
#                                         114688,
#                                         2752516,
#                                         70829,
#                                         1367504,
#                                         1464081,
#                                         1464070,
#                                         1266771,
#                                         910542,
#                                         284030,
#                                         3075518,
#                                         2748864,
#                                         2883101,
#                                         1942,
#                                         100753,
#                                         121022,
#                                         68211,
#                                         2875706,
#                                         933940,
#                                         3033808,
#                                         516455,
#                                         284452,
#                                         68209,
#                                         1520565,
#                                         285476,
#                                         249580,
#                                         284029,
#                                         284044,
#                                         2306504,
#                                         77853,
#                                         1907,
#                                         363866,
#                                         1812259,
#                                         553510,
#                                         1550617,
#                                         3075529,
#                                         2058923,
#                                         2768068,
#                                         114689,
#                                         285548,
#                                         285446,
#                                         68206,
#                                         235466,
#                                         66892,
#                                         68205,
#                                         285443,
#                                         1649596,
#                                         1763542,
#                                         1520513,
#                                         33899,
#                                         33898,
#                                         3048495,
#                                         1528880,
#                                         1324013,
#                                         68203,
#                                         66371,
#                                         67302,
#                                         66891,
#                                         285535,
#                                         284028,
#                                         1348284,
#                                         152141,
#                                         67301,
#                                         1906,
#                                         641806,
#                                         1616117,
#                                         1904616,
#                                         3385496,
#                                         284031,
#                                         66888,
#                                         285465,
#                                         285464,
#                                         453818,
#                                         68200,
#                                         68199,
#                                         67298,
#                                         67297,
#                                         2665155,
#                                         67296,
#                                         68197,
#                                         66887,
#                                         375757,
#                                         67294,
#                                         1977088,
#                                         1413221,
#                                         713595,
#                                         66886,
#                                         1520528,
#                                         2662397,
#                                         1550620,
#                                         2981351,
#                                         1905,
#                                         3075535,
#                                         42237,
#                                         207915,
#                                         146819,
#                                         66423,
#                                         1965,
#                                         285574,
#                                         333728,
#                                         714166,
#                                         2991496,
#                                         2898945,
#                                         68195,
#                                         3075527,
#                                         68898,
#                                         67293,
#                                         2969338,
#                                         909626,
#                                         2811104,
#                                         319947,
#                                         68194,
#                                         2448886,
#                                         3075533,
#                                         202862,
#                                         3075536,
#                                         3075528,
#                                         68193,
#                                         2981601,
#                                         42236,
#                                         2849069,
#                                         2800381,
#                                         531967,
#                                         2666184,
#                                         2049881,
#                                         436509,
#                                         588122,
#                                         249567,
#                                         424188,
#                                         348043,
#                                         1472640,
#                                         1442032,
#                                         248040,
#                                         299421,
#                                         66885,
#                                         1470456,
#                                         2981134,
#                                         2927583,
#                                         1521758,
#                                         80860,
#                                         67291,
#                                         1904,
#                                         68192,
#                                         2496836,
#                                         2715922,
#                                         66882,
#                                         146536,
#                                         2759956,
#                                         2962890,
#                                         68191,
#                                         66881,
#                                         67290,
#                                         2282652,
#                                         1128680,
#                                         28043,
#                                         2864460,
#                                         1903,
#                                         66880,
#                                         2851888,
#                                         1653203,
#                                         2720025,
#                                         1428652,
#                                         68190,
#                                         42684,
#                                         621382,
#                                         29304,
#                                         116188,
#                                         285563,
#                                         66879,
#                                         2800379,
#                                         285547,
#                                         1515090,
#                                         285562,
#                                         67289,
#                                         647381,
#                                         1901,
#                                         68188,
#                                         3118173,
#                                         212427,
#                                         67288,
#                                         68187,
#                                         1520517,
#                                         1481185,
#                                         285543,
#                                         67287,
#                                         319633,
#                                         66422,
#                                         1955,
#                                         285561,
#                                         67260,
#                                         248131,
#                                         1214925,
#                                         68186,
#                                         285452,
#                                         42881,
#                                         68185,
#                                         887452,
#                                         1257027,
#                                         3075540,
#                                         307501,
#                                         1194079,
#                                         766497,
#                                         312720,
#                                         3040919,
#                                         3053466,
#                                         66876,
#                                         1969,
#                                         2964669,
#                                         280960,
#                                         1807875,
#                                         1968,
#                                         2800378,
#                                         58344,
#                                         67285,
#                                         230087,
#                                         67258,
#                                         3043613,
#                                         2259034,
#                                         3031124,
#                                         66875,
#                                         3033811,
#                                         285463,
#                                         79261,
#                                         1897,
#                                         66369,
#                                         285558,
#                                         67284,
#                                         2665496,
#                                         44059,
#                                         1464056,
#                                         1840415,
#                                         68183,
#                                         2014920,
#                                         68182,
#                                         2746961,
#                                         285557,
#                                         67283,
#                                         285453,
#                                         2041421,
#                                         1768092,
#                                         1616125,
#                                         1616122,
#                                         1287524,
#                                         3004093,
#                                         67282,
#                                         67351,
#                                         1485586,
#                                         3134107,
#                                         1682723,
#                                         2070367,
#                                         53502,
#                                         68181,
#                                         661399,
#                                         2307231,
#                                         36816,
#                                         1898,
#                                         1678637,
#                                         1452742,
#                                         285568,
#                                         349910,
#                                         3098223,
#                                         2763006,
#                                         2495589,
#                                         285498,
#                                         2686304,
#                                         1486858,
#                                         887462,
#                                         2736302,
#                                         1954,
#                                         42235,
#                                         2486417,
#                                         2039455,
#                                         2711219,
#                                         1775135,
#                                         1431344,
#                                         3075541,
#                                         67280,
#                                         33897,
#                                         2569855,
#                                         68180,
#                                         379067,
#                                         1896,
#                                         66874,
#                                         1337893,
#                                         2971913,
#                                         2595054,
#                                         163361,
#                                         2984495,
#                                         2841597,
#                                         2340725,
#                                         2710756,
#                                         2892029,
#                                         1257026,
#                                         1036731,
#                                         295352,
#                                         1550616,
#                                         542764,
#                                         1941,
#                                         146537,
#                                         552788,
#                                         1895,
#                                         500153,
#                                         33903,
#                                         75293,
#                                         67278,
#                                         193461,
#                                         66871,
#                                         67277,
#                                         67276,
#                                         531296,
#                                         1218961,
#                                         114687,
#                                         66870,
#                                         2838335,
#                                         285462,
#                                         285556,
#                                         285461,
#                                         68177,
#                                         285460,
#                                         545121,
#                                         1893,
#                                         1663240,
#                                         531966,
#                                         68176,
#                                         249586,
#                                         1520514,
#                                         1905151,
#                                         476551,
#                                         481002,
#                                         285553,
#                                         83291,
#                                         1864853,
#                                         2726118,
#                                         1295550,
#                                         41951,
#                                         29301,
#                                         67273,
#                                         285564,
#                                         1705607,
#                                         2600619,
#                                         544311,
#                                         2548456,
#                                         2021638,
#                                         1828112,
#                                         2654677,
#                                         2494256,
#                                         306682,
#                                         1507734,
#                                         68175,
#                                         2883108,
#                                         1891,
#                                         1890,
#                                         429003,
#                                         115647,
#                                         285578,
#                                         1565035,
#                                         2675858,
#                                         285454,
#                                         681158,
#                                         2023875,
#                                         221586,
#                                         1889,
#                                         67271,
#                                         2932828,
#                                         1854571,
#                                         2867194,
#                                         1464124,
#                                         2213162,
#                                         1472722,
#                                         1642299,
#                                         476550,
#                                         1852274,
#                                         1888,
#                                         173770,
#                                         58341,
#                                         285515,
#                                         367931,
#                                         67268,
#                                         196385,
#                                         2867120,
#                                         67267,
#                                         66866,
#                                         1940,
#                                         2897419,
#                                         1623582,
#                                         722709,
#                                         67266,
#                                         1477431,
#                                         329524,
#                                         2981135,
#                                         2569859,
#                                         329523,
#                                         68172,
#                                         68171,
#                                         40842,
#                                         2865673,
#                                         255848,
#                                         910347,
#                                         387846,
#                                         285458,
#                                         231024,
#                                         66865,
#                                         945056,
#                                         1609272,
#                                         3231367,
#                                         285493,
#                                         2796465,
#                                         270689,
#                                         1885,
#                                         1695166,
#                                         657275,
#                                         285456,
#                                         1517697,
#                                         42234,
#                                         2596892,
#                                         67255,
#                                         3134111,
#                                         574929,
#                                         933944,
#                                         97398,
#                                         1227734,
#                                         371608,
#                                         1470348],
#                            'classification': {'class': {'id': 1760,
#                                                         'name': 'Actinomycetes'},
#                                               'domain': {'id': 2,
#                                                          'name': 'Bacteria'},
#                                               'family': {'id': 2062,
#                                                          'name': 'Streptomycetaceae'},
#                                               'genus': {'id': 1883,
#                                                         'name': 'Streptomyces'},
#                                               'kingdom': {'id': 1783272,
#                                                           'name': 'Bacillati'},
#                                               'order': {'id': 85011,
#                                                         'name': 'Kitasatosporales'},
#                                               'phylum': {'id': 201174,
#                                                          'name': 'Actinomycetota'}},
#                            'counts': [{'count': 12394,
#                                        'type': 'COUNT_TYPE_ASSEMBLY'},
#                                       {'count': 946143,
#                                        'type': 'COUNT_TYPE_GENE'},
#                                       {'count': 8893,
#                                        'type': 'COUNT_TYPE_tRNA'},
#                                       {'count': 1921,
#                                        'type': 'COUNT_TYPE_rRNA'},
#                                       {'count': 912129,
#                                        'type': 'COUNT_TYPE_PROTEIN_CODING'},
#                                       {'count': 122,
#                                        'type': 'COUNT_TYPE_miscRNA'},
#                                       {'count': 244,
#                                        'type': 'COUNT_TYPE_ncRNA'}],
#                            'current_scientific_name': {'authority': 'Waksman '
#                                                                     'and '
#                                                                     'Henrici '
#                                                                     '1943 '
#                                                                     '(Approved '
#                                                                     'Lists '
#                                                                     '1980)',
#                                                        'name': 'Streptomyces'},
#                            'current_scientific_name_is_formal': True,
#                            'genomic_moltype': 'dsDNA',
#                            'group_name': 'high G+C Gram-positive bacteria',
#                            'parents': [1,
#                                        131567,
#                                        2,
#                                        1783272,
#                                        201174,
#                                        1760,
#                                        85011,
#                                        2062],
#                            'rank': 'GENUS',
#                            'secondary_tax_ids': [65506, 31945, 1973],
#                            'tax_id': 1883}}],
#  'total_count': 1}

# %% [markdown]
# Using WikiData

# %% [markdown]
# ![images/wikidata-wiki.png](images/wikidata-wiki.png)

# %%
import requests
import pprint

WIKIDATA_SPARQL_URL = "https://query.wikidata.org/sparql"
HEADERS = {"Accept": "application/sparql-results+json"}

def run_sparql_query(query: str) -> dict:
    """Run a SPARQL query and return the JSON result."""
    response = requests.get(WIKIDATA_SPARQL_URL, headers=HEADERS, params={"query": query})
    response.raise_for_status()
    return response.json()

def get_entity_id_by_label(label: str, language: str = "en") -> str:
    """
    Finds the Wikidata entity ID for a given label (name).
    """
    query = f"""
    SELECT ?item WHERE {{
      # ?item rdfs:label "{label}"@{language} .
    }}
    LIMIT 1
    """
    data = run_sparql_query(query)
    if "results" not in data or "bindings" not in data["results"]:
        raise ValueError(f"Unexpected response format from Wikidata for label '{label}': {data}")
    bindings = data["results"]["bindings"]
    if not bindings:
        raise ValueError(f"No Wikidata entity found for label '{label}'")
    if "item" not in bindings[0] or "value" not in bindings[0]["item"]:
        raise ValueError(f"Missing 'item' or 'value' in SPARQL result for label '{label}': {bindings[0]}")
    entity_url = bindings[0]["item"]["value"]
    return entity_url.rsplit("/", 1)[-1]

def get_species_taxon(entity_id: str) -> str:
    """
    Returns the taxon entity ID with rank 'species' (wd:Q7432) if available.
    """
    query = f"""
    SELECT ?taxon ?taxonLabel WHERE {{
      wd:{entity_id} wdt:P703 ?taxon .
      # ?taxon wdt:P105 wd:Q7432 .  # Filter: only taxon with rank = species
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en". }}
    }}
    LIMIT 1
    """
    data = run_sparql_query(query)
    if "results" not in data or "bindings" not in data["results"]:
        raise ValueError(f"Unexpected response format from Wikidata for entity {entity_id}: {data}")
    bindings = data["results"]["bindings"]
    if not bindings:
        raise ValueError(f"No species-level taxon found for entity {entity_id}")
    if "taxon" not in bindings[0] or "value" not in bindings[0]["taxon"]:
        raise ValueError(f"Missing 'taxon' or 'value' in SPARQL result for entity {entity_id}: {bindings[0]}")
    taxon_url = bindings[0]["taxon"]["value"]
    return taxon_url.rsplit("/", 1)[-1]


def get_entity_properties(entity_id: str, limit: int = 300) -> dict:
    """Get a dictionary of property → value labels for a given Wikidata entity."""
    query = f"""
    SELECT ?propertyLabel ?valueLabel WHERE {{
      wd:{entity_id} ?prop ?value .
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en". }}
    }} LIMIT {limit}
    """
    return run_sparql_query(query)

def get_entity_label(entity_id: str) -> str:
    """
    Returns the label (name) of a Wikidata entity.
    """
    query = f"""
    SELECT ?itemLabel WHERE {{
      wd:{entity_id} rdfs:label ?itemLabel .
      FILTER (lang(?itemLabel) = "en")
    }}
    LIMIT 1
    """
    data = run_sparql_query(query)
    if "results" not in data or "bindings" not in data["results"]:
        raise ValueError(f"Unexpected response format from Wikidata for entity {entity_id}: {data}")
    bindings = data["results"]["bindings"]
    if not bindings:
        raise ValueError(f"No label found for entity {entity_id}")
    if "itemLabel" not in bindings[0] or "value" not in bindings[0]["itemLabel"]:
        raise ValueError(f"Missing 'itemLabel' or 'value' in SPARQL result for entity {entity_id}: {bindings[0]}")
    return bindings[0]["itemLabel"]["value"]

# %%
# Step 0: Find the Wikidata ID for "Surugamide A"
source_entity_name = "Surugamide A"
source_entity_id = get_entity_id_by_label(source_entity_name)
print(f"The Wikidata ID for '{source_entity_name}' is: {source_entity_id}")

print(f"\nLooking up taxon for Wikidata entity: {source_entity_name} ({source_entity_id})")

# Step 1: Get the taxon entity linked via "found in taxon" (P703)
taxon_entity_id = get_species_taxon(source_entity_id)
print(f"Found in taxon entity ID: {taxon_entity_id}")

# Step 2: Get the label for the taxon entity
taxon_entity_label = get_entity_label(taxon_entity_id)
print(f"Found in taxon entity name: {taxon_entity_label}")


# Step 3: Get properties of the taxon entity
taxon_properties = get_entity_properties(taxon_entity_id)

print("\nTaxon properties:")
pprint.pprint(taxon_properties)
# Out:
# The Wikidata ID for 'Surugamide A' is: Q77372486
#
# Looking up taxon for Wikidata entity: Surugamide A (Q77372486)
# Found in taxon entity ID: Q22286833
# Found in taxon entity name: Streptomyces albidoflavus
#
# Taxon properties:
# {'head': {'vars': ['propertyLabel', 'valueLabel']},
#  'results': {'bindings': [{'valueLabel': {'type': 'literal',
#                                           'value': '2248300457'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': '2024-09-14T23:06:01Z'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'specie de bacterie'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Art der Gattung '
#                                                    'Streptomyces'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'vrsta bakterij v rodu '
#                                                    'Streptomyces'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'species of '
#                                                    'Actinobacteria'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'вид актинобактерій'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'soort uit het geslacht '
#                                                    'Streptomyces'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'speiceas Actinobacteria'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': '스트렙토미세스속에 속하는 세균'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': '스트렙토미세스 알비도플라부스'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal', 'value': '44'}},
#                           {'valueLabel': {'type': 'literal', 'value': '3'}},
#                           {'valueLabel': {'type': 'literal', 'value': '38'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'taxon',
#                                           'xml:lang': 'en'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'species',
#                                           'xml:lang': 'en'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces',
#                                           'xml:lang': 'en'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'Streptomyces '
#                                                    'albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-70CFE6FD-2A17-48F4-A3DD-4763C49AE60A'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-FD172634-A21C-4F4E-B93E-75AC8B1D0F77'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-FA4F3F95-F4BA-423C-BF64-A3BD058880B7'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-4E2013A9-20E0-44A1-9F76-8FC19E7746E3'}},
#                           {'valueLabel': {'type': 'literal', 'value': '1886'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': '966732'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': '972226'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': '3223983'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'https://lpsn.dsmz.de/species/streptomyces-albidoflavus'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'gram-positive bacteria',
#                                           'xml:lang': 'en'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': '/g/11bwgwh3yx'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': '8d23ee36-945d-4f89-ad1e-461ee76492dd'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'C0995727'}},
#                           {'valueLabel': {'type': 'literal', 'value': '14904'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_000156475.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_000717375.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_000719955.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_001509565.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_001865795.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_002808645.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_004078575.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_004195735.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_004195845.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_004195945.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_004196045.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_004196125.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_006378235.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_007896905.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_015321285.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_015601545.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_016734825.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_016734865.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_019219685.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_019286195.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_019286295.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_023502165.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_024592655.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'GCA_900171555.1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': '10988612'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': '2778293847'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': '772836'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'C2780681812'}},
#                           {'valueLabel': {'type': 'literal', 'value': '52Y8F'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': '82ec422b-d9e7-4046-a3f1-efd5872bed8a'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'http://purl.uniprot.org/taxonomy/1886'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'http://g.co/kg/g/11bwgwh3yx'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'urn:lsid:irmng.org:taxname:10988612'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'https://makg.org/entity/2778293847'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-244717B0-A83F-493E-B3A4-50D53507E83E'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-3E9B5777-A75C-4F87-AA01-EFFABBDBE54E'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-E58845E4-B9F3-4987-9FC8-F77A6AD55DAC'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-93E1AB2F-4133-4A6F-854F-E4605221FA90'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-1BE65355-6EDB-4AC1-A5AC-D99FC1A5EF8F'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-BB89769F-77C5-48B1-8ED2-48D83C0D9B95'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-8ED7D010-F43D-44C6-8B1E-E08A7D7D62B5'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-9BBA9838-EDE7-4A72-8E65-5DC9AA3FA576'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-C2AAA3CA-A722-413F-BAC5-FEE7B9CB1B21'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-6AB66B46-80AD-4792-B8F0-5DFF9EC72151'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-050F1DC5-C12A-4157-A414-F2166FF2623C'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-1516FD45-0CBC-4246-B826-68548542EF67'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-1E4C00D1-20B4-45BD-B93F-63D95D933C2D'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-211E2271-B3A2-418F-84BD-5E04853C2800'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-2640B69C-AFC2-4543-B9F2-2D3AF6749E72'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-30F8EB9F-A092-4559-8BCD-F2BF5567CB1D'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-32806745-6F19-41B9-A870-EF310310C4B7'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-557B5581-BCE0-493F-A145-BC556CC97940'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-61FE545A-EFBF-40BF-BD14-E64D734FF3EE'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-76A04513-6191-4318-9C94-595615AFBEB6'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-77A0B614-2952-44B0-AA63-011C6ECA14B4'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-87D8530D-3DB4-4FBA-B863-468B713AA4A1'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-913F3198-58DB-44D9-A86B-C354C6235F9C'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-A19953B1-56EC-4393-8504-FFB6E7E3E573'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-B0D8647D-41C5-4B4D-A2A3-8CC37FA06ECA'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-B36FD27B-1F41-487F-89E0-F5DF75BDF55E'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-B70B7D9C-4C77-4981-BB42-884F934886C6'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-BAF9FCB0-1AC1-4262-A8DA-5CEF638187AC'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-BF3A10C7-8CE1-4799-BB7D-F8D3FBCDAAEB'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-C4936D1B-5381-40BB-AC29-1ACFE1FFD6FD'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-CA553045-BE96-4C4B-BE42-97C17E4D6106'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-CBF873EF-20BF-4165-8A9B-6AD5DB02A3C5'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-DC5EEDB4-E741-4138-A899-08126764A43D'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-EDB27915-F663-4CA1-BE6F-55B5EFA1D441'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-EDC0B921-2751-4EEB-8C1A-29BE4BEB744F'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-66D357DE-60FE-49EF-B533-FC786B8F6B81'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-1980ED24-ABFD-439A-8889-B99148208B98'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-CFB9A119-C59D-4B17-8CAF-FDE42BB25931'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-B436E1EE-2042-4AB4-97B2-1C89474A95EE'}},
#                           {'valueLabel': {'type': 'literal',
#                                           'value': 'statement/Q22286833-E4AE2CF3-F3D9-4B24-9368-D1B49B4D03A5'}}]}}

# %%
from dataclasses import dataclass, field

@dataclass
class Result:
    compoundLabel: str = field(default="")
    pubchemCID: str = field(default="")
    inchiKey: str = field(default="")
    foundInTaxonLabel: str = field(default="")
    bioactivityLabel: str = field(default="")
    
    def __post_init__(self):
        self.compoundLabel = self.compoundLabel or "Unknown Compound"
        self.pubchemCID = self.pubchemCID or "N/A"
        self.inchiKey = self.inchiKey or "N/A"
        self.foundInTaxonLabel = self.foundInTaxonLabel or "Unknown Taxon"
        self.bioactivityLabel = self.bioactivityLabel or "N/A"



def get_compounds_found_in_taxon(taxon_entity: str, limit: int = 100) -> dict:
    query = """SELECT ?compoundLabel ?pubchemCID ?inchiKey ?foundInTaxonLabel  ?bioactivityLabel WHERE {
  # Find compounds that have "found in taxon" of Streptomyces lavendulae (Q1144013)
  # ?compound wdt:P703 wd:Q1144013 .

  # Include the found taxon in the results (it will always be Q1144013 in this case)
  BIND(wd:Q1144013 AS ?foundInTaxon)

  # Optional external identifiers
  OPTIONAL { ?compound wdt:P662 ?pubchemCID. } # PubChem CID
  OPTIONAL { ?compound wdt:P235 ?inchiKey. }   # InChIKey

  # Using P2868 (drug used for treatment) and P2175 (medical condition treated) as examples.
  OPTIONAL { ?compound wdt:P2868 ?bioactivity. }
  OPTIONAL { ?compound wdt:P2175 ?bioactivity. }

  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
LIMIT 100
    """
    data = run_sparql_query(query)
    for result in data['results']['bindings']:
        yield Result(
            compoundLabel=result.get('compoundLabel', {}).get('value', ""),
            pubchemCID=result.get('pubchemCID', {}).get('value', ""),
            inchiKey=result.get('inchiKey', {}).get('value', ""),
            foundInTaxonLabel=result.get('foundInTaxonLabel', {}).get('value', ""),
            bioactivityLabel=result.get('bioactivityLabel', {}).get('value', "")
        )

data = get_compounds_found_in_taxon("Q1144013")

# %%
data.__next__()
# Out:
# Result(compoundLabel='rifampicin', pubchemCID='5381226', inchiKey='JQXXHWHPUNPDRT-WLSIYKJHSA-N', foundInTaxonLabel='Streptomyces', bioactivityLabel='antibiotic')

# %%
data = get_compounds_found_in_taxon("Q1144013")

# %%
df = DataFrame(data)

# %%
df
# Out:
#    compoundLabel pubchemCID                     inchiKey foundInTaxonLabel  \
# 0     rifampicin    5381226  JQXXHWHPUNPDRT-WLSIYKJHSA-N      Streptomyces
# 1     rifampicin  135398735  JQXXHWHPUNPDRT-WLSIYKJHSA-N      Streptomyces
# 2     rifampicin  136262914  JQXXHWHPUNPDRT-WLSIYKJHSA-N      Streptomyces
# 3     rifampicin    5381226  JQXXHWHPUNPDRT-WLSIYKJHSA-N      Streptomyces
# 4     rifampicin  135398735  JQXXHWHPUNPDRT-WLSIYKJHSA-N      Streptomyces
# ..           ...        ...                          ...               ...
# 95    riboflavin     493570  AUNGANRZJHBGPY-SCRDCRAPSA-N      Streptomyces
# 96    riboflavin     493570  AUNGANRZJHBGPY-SCRDCRAPSA-N      Streptomyces
# 97    riboflavin     493570  AUNGANRZJHBGPY-SCRDCRAPSA-N      Streptomyces
# 98    riboflavin     493570  AUNGANRZJHBGPY-SCRDCRAPSA-N      Streptomyces
# 99      undecane      14257  RSJKGSCJYJTIGS-UHFFFAOYSA-N      Streptomyces
#
#       bioactivityLabel
# 0           antibiotic
# 1           antibiotic
# 2           antibiotic
# 3   essential medicine
# 4   essential medicine
# ..                 ...
# 95  essential medicine
# 96           vitamin B
# 97     photosensitizer
# 98  primary metabolite
# 99                 N/A
#
# [100 rows x 5 columns]
